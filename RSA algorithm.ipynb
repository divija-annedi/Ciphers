# %%
import math

p = int(input("Enter a prime number for p: "))
q = int(input("Enter a prime number for q: "))
 
def prime_check(a):
    if(a==2):
        return True
    elif((a<2) or ((a%2)==0)):
        return False
    elif(a>2):
        for i in range(2,a):
            if not(a%i):
                return false
    return True
 
check_p = prime_check(p)
check_q = prime_check(q)
while(((check_p==False)or(check_q==False))):
    p = int(input("Enter a prime number for p: "))
    q = int(input("Enter a prime number for q: "))
    check_p = prime_check(p)
    check_q = prime_check(q)
 

n = p * q
print("The value of n is:",n)
r= (p-1)*(q-1)
print("The value of (p-1)(q-1) is:",r)
 
'''CALCULATION OF GCD FOR 'e' CALCULATION.'''
def egcd(e,r):
    while(r!=0):
        e,r=r,e%r
    return e

#Extended Euclidean Algorithm
def eea(a,b):
    if(a%b==0):
        return(b,0,1)
    else:
        gcd,s,t = eea(b,a%b)
        s = s-((a//b) * t)
        gcd=a*t+s*b
        return(gcd,t,s)
 

def mult_inv(e,r):
    gcd,s,_=eea(e,r)
    if(gcd!=1):
        return None
    else:
        if(s<0):
            print("s=%d. Since %d is less than 0, s = s(modr), i.e., s=%d."%(s,s,s%r))
        elif(s>0):
            print("s=%d."%(s))
        return s%r
 
#e Value Calculation
for i in range(1,1000):
    if(egcd(i,r)==1):
        e=i
e=7
print("The value of e is:",e)

d = mult_inv(e,r)
print("The value of d is:",d)
public = (e,n)
private = (d,n)
print("Private Key is:",private)
print("Public Key is:",public)
M=int(input("Enter a value of M:"))
if M<n:
    print("Encryption: C=M^e mod n")
    C=pow(M,e,n)
    print("C = ",C)
    print("Decryption: D=C^d mod n")
    D=pow(C,d,n)
    print("D = ",D)
else:
    print("The value of M should be less than the value of n")
# Out:
# Enter a prime number for p: 11
# Enter a prime number for q: 13
# The value of n is: 143
# The value of (p-1)(q-1) is: 120
# The value of e is: 7
# s=-17. Since -17 is less than 0, s = s(modr), i.e., s=103.
# The value of d is: 103
# Private Key is: (103, 143)
# Public Key is: (7, 143)
# Enter a value of M:88
# Encryption: C=M^e mod n
# C =  88
# Decryption: D=C^d mod n
# D =  88
